# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dWCy1AgFzzs5smSzZSxE")
project = rf.workspace("thee-msxvq").project("lettuce-qcfff-qfhpd-j6hae")
version = project.version(3)
dataset = version.download("yolov12")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dWCy1AgFzzs5smSzZSxE")
project = rf.workspace("thee-msxvq").project("lettuce-qcfff-qfhpd-j6hae")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.64-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.58.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# Downloading roboflow-1.1.64-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 3.8 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 46.5 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 129.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.1.0 roboflow-1.1.64
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in lettuce-3 to yolov11:: 100%|██████████| 479303/479303 [00:06<00:00, 71884.10it/s]
# Extracting Dataset Version Zip to lettuce-3 in yolov11:: 100%|██████████| 46170/46170 [00:04<00:00, 9564.80it/s]

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.143-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.143-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 101.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.3 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.143 ultralytics-thop-2.0.14

# %%
data_yaml_path = f"{dataset.location}/data.yaml"

data_yaml_content = """
train: /content/lettuce-3/train
val: /content/lettuce-3/valid
test: /content/lettuce-3/test
nc: 6
names: ['bacteria', 'Downy_mildew_on_lettuce', 'Healthy', 'Lettuce Mosaic Virus',
'Powdery_mildew_on_lettuce', 'Septoria_Blight_on_lettuce']
"""

with open(data_yaml_path, "w") as f:
    f.write(data_yaml_content.strip())

# %%
# !yolo task=detect mode=train model=yolo12n.pt data={dataset.location}/data.yaml epochs=50 imgsz=320 plots=True

# %%
# !yolo task=detect mode=train model=yolo12n.pt data={dataset.location}/data.yaml epochs=50 imgsz=224 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12n.pt to 'yolo12n.pt'...
# 100% 5.34M/5.34M [00:00<00:00, 70.1MB/s]
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/lettuce-3/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 21.7MB/s]
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    431842  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,569,218 parameters, 2,569,202 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 90.8MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 834.7±260.0 MB/s, size: 18.4 KB)
# train: Scanning /content/lettuce-3/train/labels... 21744 images, 3 backgrounds, 0 corrupt: 100% 21744/21744 [00:08<00:00, 2445.14it/s]
# train: New cache created: /content/lettuce-3/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 595, len(boxes) = 27159. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 459.7±192.9 MB/s, size: 22.8 KB)
# val: Scanning /content/lettuce-3/valid/labels... 791 images, 0 backgrounds, 0 corrupt: 100% 791/791 [00:00<00:00, 1840.24it/s]
# val: New cache created: /content/lettuce-3/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 28, len(boxes) = 980. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50     0.432G      1.286      2.947      1.499         49        224: 100% 1359/1359 [03:53<00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:05<00:00,  4.91it/s]
#                    all        791        980       0.46      0.501      0.431      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50     0.467G      1.246      1.966       1.46         48        224: 100% 1359/1359 [03:40<00:00,  6.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  6.33it/s]
#                    all        791        980      0.451      0.474        0.4      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50     0.477G      1.261      1.959      1.441         49        224: 100% 1359/1359 [03:34<00:00,  6.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:04<00:00,  5.35it/s]
#                    all        791        980      0.413      0.463      0.411      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50     0.486G       1.25      1.883      1.419         41        224: 100% 1359/1359 [03:32<00:00,  6.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  6.46it/s]
#                    all        791        980      0.466      0.577      0.518      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50     0.496G      1.187      1.723      1.385         47        224: 100% 1359/1359 [03:31<00:00,  6.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  6.37it/s]
#                    all        791        980      0.623      0.587       0.61      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50     0.506G      1.134      1.602      1.348         51        224: 100% 1359/1359 [03:35<00:00,  6.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  6.48it/s]
#                    all        791        980      0.691      0.637      0.681      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50     0.516G      1.106      1.508      1.331         50        224: 100% 1359/1359 [03:33<00:00,  6.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  6.40it/s]
#                    all        791        980      0.696      0.699      0.728      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50     0.525G      1.081      1.437      1.315         51        224: 100% 1359/1359 [03:30<00:00,  6.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:04<00:00,  5.45it/s]
#                    all        791        980      0.744      0.709       0.75      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50     0.535G      1.058      1.379      1.298         64        224: 100% 1359/1359 [03:30<00:00,  6.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:04<00:00,  6.03it/s]
#                    all        791        980      0.768      0.735      0.783      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50     0
0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.19G     0.6504     0.4514      1.086         20        320: 100% 1359/1359 [02:08<00:00, 10.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.71it/s]
#                    all        791        980      0.914      0.891       0.91      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       1.2G     0.6439     0.4466      1.082         18        320: 100% 1359/1359 [02:09<00:00, 10.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.79it/s]
#                    all        791        980       0.92      0.892       0.91      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.21G       0.63     0.4275      1.072         24        320: 100% 1359/1359 [02:08<00:00, 10.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.78it/s]
#                    all        791        980      0.917        0.9      0.911      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.22G     0.6118     0.4095      1.061         18        320: 100% 1359/1359 [02:08<00:00, 10.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.82it/s]
#                    all        791        980      0.915      0.902      0.911      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.23G     0.6025     0.4024      1.058         18        320: 100% 1359/1359 [02:08<00:00, 10.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.65it/s]
#                    all        791        980      0.918      0.905      0.912      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.24G     0.5927     0.3897      1.051         23        320: 100% 1359/1359 [02:08<00:00, 10.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.99it/s]
#                    all        791        980      0.919      0.909      0.912      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.25G     0.5781     0.3772      1.043         16        320: 100% 1359/1359 [02:08<00:00, 10.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.74it/s]
#                    all        791        980      0.919      0.911      0.913      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.26G     0.5727      0.371      1.039         22        320: 100% 1359/1359 [02:09<00:00, 10.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.70it/s]
#                    all        791        980       0.92      0.908      0.913      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.27G     0.5633     0.3651      1.037         18        320: 100% 1359/1359 [02:08<00:00, 10.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:03<00:00,  7.98it/s]
#                    all        791        980      0.921      0.906      0.913      0.758
#
# 50 epochs completed in 1.824 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.4MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.4MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 25/25 [00:04<00:00,  6.09it/s]
#                    all        791        980      0.921      0.906      0.913      0.758
#               bacteria        127        176      0.968      0.859       0.88      0.751
# Downy_mildew_on_lettuce        138        153      0.903      0.961      0.949      0.816
#                Healthy        150        170      0.994      0.974      0.985      0.745
#   Lettuce Mosaic Virus        107        122      0.888      0.979      0.932      0.813
# Powdery_mildew_on_lettuce        129        186      0.856      0.715      0.758      0.574
# Septoria_Blight_on_lettuce        144        173      0.916      0.949      0.976      0.848
# Speed: 0.0ms preprocess, 0.4ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=50 imgsz=224 plots=True

# %%
from IPython.display import Image, display
#Yolov12n (320px)
folder = "/content/runs/detect/train"

# Tampilkan confusion matrix
display(Image(filename=f"{folder}/confusion_matrix.png"))

# Tampilkan precision-recall curve
display(Image(filename=f"{folder}/PR_curve.png"))

# Tampilkan F1 curve
display(Image(filename=f"{folder}/F1_curve.png"))
# Tampilkan result
display(Image(filename=f"{folder}/results.png"))

# Tampilkan P, R, mAP50, mAP50-95, loss (training summary)
import pandas as pd

results_path = f"{folder}/results.csv"
df = pd.read_csv(results_path)
display(df.tail(1))  # menampilkan hasil epoch terakhir
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 49     50  6566.89         0.56329         0.36507         1.03692
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 49                0.9208            0.90618           0.91321
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 49              0.75772       0.72675       0.50375       0.89094  0.000298
#
#       lr/pg1    lr/pg2
# 49  0.000298  0.000298

# %%
from IPython.display import Image, display

# Yolov12n (224px)
folder = "/content/runs/detect/train2"

# Tampilkan confusion matrix
display(Image(filename=f"{folder}/confusion_matrix.png"))

# Tampilkan precision-recall curve
display(Image(filename=f"{folder}/PR_curve.png"))

# Tampilkan F1 curve
display(Image(filename=f"{folder}/F1_curve.png"))
# Tampilkan result
display(Image(filename=f"{folder}/results.png"))

# Tampilkan P, R, mAP50, mAP50-95, loss (training summary)
import pandas as pd

results_path = f"{folder}/results.csv"
df = pd.read_csv(results_path)
display(df.tail(1))  # menampilkan hasil epoch terakhir
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 49     50  10868.4         0.59857         0.39102         1.04225
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 49               0.92116             0.8873            0.9148
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 49               0.7424       0.82127       0.54837       0.94772  0.000298
#
#       lr/pg1    lr/pg2
# 49  0.000298  0.000298

# %%
from IPython.display import Image, display

# Yolov11 (320px)
folder = "/content/runs/detect/train3"

# Tampilkan confusion matrix
display(Image(filename=f"{folder}/confusion_matrix.png"))

# Tampilkan precision-recall curve
display(Image(filename=f"{folder}/PR_curve.png"))

# Tampilkan F1 curve
display(Image(filename=f"{folder}/F1_curve.png"))
# Tampilkan result
display(Image(filename=f"{folder}/results.png"))

# Tampilkan P, R, mAP50, mAP50-95, loss (training summary)
import pandas as pd

results_path = f"{folder}/results.csv"
df = pd.read_csv(results_path)
display(df.tail(1))  # menampilkan hasil epoch terakhir

# %%
from IPython.display import Image, display

# Yolov11 (224px)
folder = "/content/runs/detect/trai4"

# Tampilkan confusion matrix
display(Image(filename=f"{folder}/confusion_matrix.png"))

# Tampilkan precision-recall curve
display(Image(filename=f"{folder}/PR_curve.png"))

# Tampilkan F1 curve
display(Image(filename=f"{folder}/F1_curve.png"))
# Tampilkan result
display(Image(filename=f"{folder}/results.png"))

# Tampilkan P, R, mAP50, mAP50-95, loss (training summary)
import pandas as pd

results_path = f"{folder}/results.csv"
df = pd.read_csv(results_path)
display(df.tail(1))  # menampilkan hasil epoch terakhir

# %%
from ultralytics import YOLO
# Test Load Model for Separate model
# Load model best PT Yolov12n(320)
model = YOLO('/content/runs/detect/train/weights/best.pt')
# Load model best PT Yolov12n(224)
model = YOLO('/content/runs/detect/train2/weights/best.pt')
# Load model best PT Yolov11n(320)
model = YOLO('/content/runs/detect/train3/weights/best.pt')
# Load model best PT Yolov11n(224)
model = YOLO('/content/runs/detect/train4/weights/best.pt')

# %%
from ultralytics import YOLO
# Test Load Model for Separate model
# Load model last PT Yolov12n(320)
model = YOLO('/content/runs/detect/train/weights/last.pt')
# Load model last PT Yolov12n(224)
model = YOLO('/content/runs/detect/train2/weights/last.pt')
# Load model last PT Yolov11n(320)
model = YOLO('/content/runs/detect/train3/weights/last.pt')
# Load model last PT Yolov11n(224)
model = YOLO('/content/runs/detect/train4/weights/last.pt')

# %%
#test Prediction from load model
results = model.predict(source='/content/164_jpg.rf.777d75b823d7a72ad21b0533ae9e9978.jpg', save=True, conf=0.5)
# Out:
# image 1/1 /content/164_jpg.rf.777d75b823d7a72ad21b0533ae9e9978.jpg: 320x320 1 Powdery_mildew_on_lettuce, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict3

# %%
from IPython.display import Image, display
import os

# Check the Result from folder 'runs/detect/predict'
output_image_path = "/content/runs/detect/predict3/164_jpg.rf.777d75b823d7a72ad21b0533ae9e9978.jpg"
if os.path.exists(output_image_path):
    display(Image(filename=output_image_path))
else:
    print("Image not Found.")

# %%
from ultralytics import YOLO

# Load the YOLO11-YOLO12 besto or last model
# You can change the train weight
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Export the model to TFLite format
model.export(format="tflite")  # creates 'yolo11n_float32.tflite'

# Load the exported TFLite model
tflite_model = YOLO("/content/runs/detect/train/weights/best_saved_model/best_float32.tflite")

# Run inference to test the model
results = tflite_model("/content/IMG_20250426_102905.jpg")
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Int
TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   137523048906000: TensorSpec(shape=(1, 1, 64, 6), dtype=tf.float32, name=None)
#   137523048902736: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   137523048896784: TensorSpec(shape=(1, 1, 64, 6), dtype=tf.float32, name=None)
#   137523048895440: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   137523051728528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137523051729488: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   137523048902352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137523048905040: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   137523048895632: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137523048898128: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   137523051731792: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051730064: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051732176: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   137523051731600: TensorSpec(shape=(1, 4, 2100), dtype=tf.float32, name=None)
#   137523051733328: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051734096: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051731216: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051732560: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051732368: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#   137523051732944: TensorSpec(shape=(1, 2, 2100), dtype=tf.float32, name=None)
#   137523051730448: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   137523051729680: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
# TensorFlow SavedModel: export success ✅ 33.6s, saved as '/content/runs/detect/train/weights/best_saved_model' (25.4 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/runs/detect/train/weights/best_saved_model/best_float32.tflite' (10.0 MB)
#
# Export complete (34.0s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best_saved_model/best_float32.tflite imgsz=320
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best_saved_model/best_float32.tflite imgsz=320 data=/content/lettuce-3/data.yaml
# Visualize:       https://netron.app

# %%
# if using onnx  to convert model onnx to tensorflow
# !onnx2tf -i /content/runs/detect/train/weights/best.onnx
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_2
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Split_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_7/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_58/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
#
# INFO: 83 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_5
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_9/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_59/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 84 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.0/m.0.1/attn/MatMul
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/attn/Split_output_1 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.compat.v1.transpose_58/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.strided_slice_8/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_5/MatMul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 85 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.0/m.0.1/attn/Reshape_4
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_59/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# INFO:  output.1.output: name: tf.reshape_20/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 86 / 500
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/m.0.1/attn/Mul
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_6_output_0 shape: () dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_64/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_71/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 87 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_7
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_20/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_65/transpose:0 shape: (1, 64, 14, 14) dtype: <dtype: 'float32'>
#
# INFO: 88 / 500
# INFO: onnx_op_type: Softmax onnx_op_name: /model.6/m.0/m.0.1/attn/Softmax
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.math.multiply_71/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 3
# INFO:  output.1.output: name: tf.nn.softmax_3/wa/model.6/m.0/m.0.1/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 89 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m.0.1/attn/pe/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.0.1.attn.pe.conv.weight shape: [64, 1, 7, 7] dtype: float32
# INFO:  input_name.3: model.6.m.0.1.attn.pe.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/pe/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: GroupedConvolution2D
# INFO:  input.1.input: name: tf.compat.v1.transpose_66/transpose:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 64
# INFO:  output.1.output: name: tf.math.add_29/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 90 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_3
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.nn.softmax_3/wa/model.6/m.0/m.0.1/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_67/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 91 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.0/m.0.1/attn/MatMul_1
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.strided_slice_9/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.compat.v1.transpose_67/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_7/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
#
# INFO: 92 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_4
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.linalg.matmul_7/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_68/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 93 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.0/m.0.1/attn/Reshape_3
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Reshape_5_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_68/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# INFO:  output.1.output: name: tf.reshape_23/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 94 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.0/m.0.1/attn/Transpose_6
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Reshape_5_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Transpose_6_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_23/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_73/transpose:0 shape: (1, 64, 14, 14) dtype: <dtype: 'float32'>
#
# INFO: 95 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.0/m.0.1/attn/Add
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Transpose_6_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/attn/pe/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_29/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_74/transpose:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_31/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 96 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m.0.1/attn/proj/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m.0.1/attn/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.0.1.attn.proj.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.0.1.attn.proj.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/attn/proj/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_31/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_32/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 97 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.0/m.0.1/Add
# INFO:  input_name.1: /model.6/m.0/m.0.0/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/attn/proj/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_27/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_32/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_34/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 98 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m.0.1/mlp/mlp.0/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m.0.1/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.0.1.mlp.0.conv.weight shape: [128, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.0.1.mlp.0.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_34/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_35/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 99 / 500
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/m.0.1/mlp/mlp.0/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/act/Sigmoid_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_35/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 100 / 500
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/m.0.1/mlp/mlp.0/act/Mul
# INFO:  input_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/mlp/mlp.0/act/Sigmoid_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/act/Mul_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_35/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_79/Mul:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 101 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m.0.1/mlp/mlp.1/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m.0.1/mlp/mlp.0/act/Mul_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.0.1.mlp.1.conv.weight shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.0.1.mlp.1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/mlp/mlp.1/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_79/Mul:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_36/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 102 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.0/m.0.1/Add_1
# INFO:  input_name.1: /model.6/m.0/m.0.1/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.1/mlp/mlp.1/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m.0.1/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_34/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_36/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_38/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 103 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.0/attn/qkv/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m.0.1/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.0.attn.qkv.conv.weight shape: [192, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.1.0.attn.qkv.conv.bias shape: [192] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/qkv/conv/Conv_output_0 shape: [1, 192, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_38/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 192) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (192,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_39/Add:0 shape: (1, 14, 14, 192) dtype: <dtype: 'float32'>
#
# INFO: 104 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.0/attn/Reshape
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/qkv/conv/Conv_output_0 shape: [1, 192, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Concat_output_0 shape: (3,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Reshape_output_0 shape: [1, 192, 196] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_81/transpose:0 shape: (1, 192, 14, 14) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(192), np.int64(-1)]
# INFO:  output.1.output: name: tf.reshape_26/Reshape:0 shape: (1, 192, 196) dtype: <dtype: 'float32'>
#
# INFO: 105 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Reshape_output_0 shape: [1, 192, 196] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_output_0 shape: [1, 196, 192] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_26/Reshape:0 shape: (1, 192, 196) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 1]
# INFO:  output.1.output: name: tf.compat.v1.transpose_84/transpose:0 shape: (1, 196, 192) dtype: <dtype: 'float32'>
#
# INFO: 106 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.0/attn/Reshape_1
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_output_0 shape: [1, 196, 192] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_5_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Reshape_2_output_0 shape: [4, 49, 2, 96] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_84/transpose:0 shape: (1, 196, 192) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(4), np.int64(49), np.int64(2), np.int64(96)]
# INFO:  output.1.output: name: tf.reshape_29/Reshape:0 shape: (4, 49, 2, 96) dtype: <dtype: 'float32'>
#
# INFO: 107 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_1
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Reshape_2_output_0 shape: [4, 49, 2, 96] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_1_output_0 shape: [4, 2, 96, 49] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_29/Reshape:0 shape: (4, 49, 2, 96) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 3, 1]
# INFO:  output.1.output: name: tf.compat.v1.transpose_89/transpose:0 shape: (4, 2, 96, 49) dtype: <dtype: 'float32'>
#
# INFO: 108 / 500
# INFO: onnx_op_type: Split onnx_op_name: /model.6/m.1/m.1.0/attn/Split
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_1_output_0 shape: [4, 2, 96, 49] dtype: float32
# INFO:  input_name.2: onnx::Split_353 shape: (3,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Split_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.2: /model.6/m.1/m.1.0/attn/Split_output_1 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.3: /model.6/m.1/m.1.0/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.compat.v1.transpose_89/transpose:0 shape: (4, 2, 96, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (3,) dtype: int64
# INFO:  input.3.axis: val: 2
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice_10/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_11/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  output.3.output2: name: tf.strided_slice_12/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
#
# INFO: 109 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_2
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Split_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_10/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_90/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
#
# INFO: 110 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_5
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_12/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_91/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 111 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.1/m.1.0/attn/MatMul
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/attn/Split_output_1 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.compat.v1.transpose_90/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.strided_slice_11/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_9/MatMul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 112 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.0/attn/Reshape_4
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_91/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# INFO:  output.1.output: name: tf.reshape_32/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 113 / 500
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.1/m.1.0/attn/Mul
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_6_output_0 shape: () dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_96/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_84/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 114 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_7
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_32/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_97/transpose:0 shape: (1, 64, 14, 14) dtype: <dtype: 'float32'>
#
# INFO: 115 / 500
# INFO: onnx_op_type: Softmax onnx_op_name: /model.6/m.1/m.1.0/attn/Softmax
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.math.multiply_84/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 3
# INFO:  output.1.output: name: tf.nn.softmax_5/wa/model.6/m.1/m.1.0/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 116 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.0/attn/pe/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.0.attn.pe.conv.weight shape: [64, 1, 7, 7] dtype: float32
# INFO:  input_name.3: model.6.m.1.0.attn.pe.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/pe/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: GroupedConvolution2D
# INFO:  input.1.input: name: tf.compat.v1.transpose_98/transpose:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 64
# INFO:  output.1.output: name: tf.math.add_40/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 117 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_3
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.nn.softmax_5/wa/model.6/m.1/m.1.0/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_99/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 118 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.1/m.1.0/attn/MatMul_1
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.strided_slice_12/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.compat.v1.transpose_99/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_11/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
#
# INFO: 119 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_4
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.linalg.matmul_11/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_100/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 120 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.0/attn/Reshape_3
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Reshape_5_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_100/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# INFO:  output.1.output: name: tf.reshape_35/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 121 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.0/attn/Transpose_6
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Reshape_5_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Transpose_6_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_35/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_105/transpose:0 shape: (1, 64, 14, 14) dtype: <dtype: 'float32'>
#
# INFO: 122 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.1/m.1.0/attn/Add
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Transpose_6_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/attn/pe/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_40/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.compat.v1.transpose_106/transpose:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_42/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 123 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.0/attn/proj/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.0/attn/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.0.attn.proj.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.1.0.attn.proj.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/attn/proj/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_42/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_43/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 124 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.1/m.1.0/Add
# INFO:  input_name.1: /model.6/m.0/m.0.1/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/attn/proj/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_38/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_43/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_45/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 125 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.0/mlp/mlp.0/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.0/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.0.mlp.0.conv.weight shape: [128, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.1.0.mlp.0.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_45/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_46/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 126 / 500
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.1/m.1.0/mlp/mlp.0/act/Sigmoid
# INFO:  input_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/act/Sigmoid_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_46/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 127 / 500
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.1/m.1.0/mlp/mlp.0/act/Mul
# INFO:  input_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/conv/Conv_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/mlp/mlp.0/act/Sigmoid_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/act/Mul_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_46/Add:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_92/Mul:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
#
# INFO: 128 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.0/mlp/mlp.1/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.0/mlp/mlp.0/act/Mul_output_0 shape: [1, 128, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.0.mlp.1.conv.weight shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.1.0.mlp.1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/mlp/mlp.1/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_92/Mul:0 shape: (1, 14, 14, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_47/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 129 / 500
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.1/m.1.0/Add_1
# INFO:  input_name.1: /model.6/m.1/m.1.0/Add_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.0/mlp/mlp.1/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.0/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_45/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_47/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_49/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 130 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.1/attn/qkv/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.0/Add_1_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.1.attn.qkv.conv.weight shape: [192, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.1.1.attn.qkv.conv.bias shape: [192] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/qkv/conv/Conv_output_0 shape: [1, 192, 14, 14] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_49/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 192) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (192,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_50/Add:0 shape: (1, 14, 14, 192) dtype: <dtype: 'float32'>
#
# INFO: 131 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.1/attn/Reshape
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/qkv/conv/Conv_output_0 shape: [1, 192, 14, 14] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Concat_output_0 shape: (3,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Reshape_output_0 shape: [1, 192, 196] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_113/transpose:0 shape: (1, 192, 14, 14) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(192), np.int64(-1)]
# INFO:  output.1.output: name: tf.reshape_38/Reshape:0 shape: (1, 192, 196) dtype: <dtype: 'float32'>
#
# INFO: 132 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Reshape_output_0 shape: [1, 192, 196] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_output_0 shape: [1, 196, 192] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_38/Reshape:0 shape: (1, 192, 196) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 1]
# INFO:  output.1.output: name: tf.compat.v1.transpose_116/transpose:0 shape: (1, 196, 192) dtype: <dtype: 'float32'>
#
# INFO: 133 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.1/attn/Reshape_1
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_output_0 shape: [1, 196, 192] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_5_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Reshape_2_output_0 shape: [4, 49, 2, 96] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_116/transpose:0 shape: (1, 196, 192) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(4), np.int64(49), np.int64(2), np.int64(96)]
# INFO:  output.1.output: name: tf.reshape_41/Reshape:0 shape: (4, 49, 2, 96) dtype: <dtype: 'float32'>
#
# INFO: 134 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_1
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Reshape_2_output_0 shape: [4, 49, 2, 96] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_1_output_0 shape: [4, 2, 96, 49] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_41/Reshape:0 shape: (4, 49, 2, 96) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 3, 1]
# INFO:  output.1.output: name: tf.compat.v1.transpose_121/transpose:0 shape: (4, 2, 96, 49) dtype: <dtype: 'float32'>
#
# INFO: 135 / 500
# INFO: onnx_op_type: Split onnx_op_name: /model.6/m.1/m.1.1/attn/Split
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_1_output_0 shape: [4, 2, 96, 49] dtype: float32
# INFO:  input_name.2: onnx::Split_353 shape: (3,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Split_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.2: /model.6/m.1/m.1.1/attn/Split_output_1 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.3: /model.6/m.1/m.1.1/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.compat.v1.transpose_121/transpose:0 shape: (4, 2, 96, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (3,) dtype: int64
# INFO:  input.3.axis: val: 2
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice_13/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_14/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  output.3.output2: name: tf.strided_slice_15/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
#
# INFO: 136 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_2
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Split_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_13/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_122/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
#
# INFO: 137 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_5
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.strided_slice_15/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_123/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 138 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.1/m.1.1/attn/MatMul
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_2_output_0 shape: [4, 2, 49, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.1/attn/Split_output_1 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.compat.v1.transpose_122/transpose:0 shape: (4, 2, 49, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.strided_slice_14/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_13/MatMul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 139 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.1/attn/Reshape_4
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_5_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_123/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# INFO:  output.1.output: name: tf.reshape_44/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 140 / 500
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.1/m.1.1/attn/Mul
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/MatMul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_6_output_0 shape: () dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.compat.v1.transpose_128/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_97/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 141 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_7
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Reshape_6_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_44/Reshape:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_129/transpose:0 shape: (1, 64, 14, 14) dtype: <dtype: 'float32'>
#
# INFO: 142 / 500
# INFO: onnx_op_type: Softmax onnx_op_name: /model.6/m.1/m.1.1/attn/Softmax
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Mul_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.math.multiply_97/Mul:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 3
# INFO:  output.1.output: name: tf.nn.softmax_7/wa/model.6/m.1/m.1.1/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 143 / 500
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.1/m.1.1/attn/pe/conv/Conv
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_7_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO:  input_name.2: model.6.m.1.1.attn.pe.conv.weight shape: [64, 1, 7, 7] dtype: float32
# INFO:  input_name.3: model.6.m.1.1.attn.pe.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/pe/conv/Conv_output_0 shape: [1, 64, 14, 14] dtype: float32
# INFO: tf_op_type: GroupedConvolution2D
# INFO:  input.1.input: name: tf.compat.v1.transpose_130/transpose:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (7, 7, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 64
# INFO:  output.1.output: name: tf.math.add_51/Add:0 shape: (1, 14, 14, 64) dtype: <dtype: 'float32'>
#
# INFO: 144 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_3
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Softmax_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.nn.softmax_7/wa/model.6/m.1/m.1.1/attn/Softmax:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 3, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_131/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
#
# INFO: 145 / 500
# INFO: onnx_op_type: MatMul onnx_op_name: /model.6/m.1/m.1.1/attn/MatMul_1
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Split_output_2 shape: [4, 2, 32, 49] dtype: float32
# INFO:  input_name.2: /model.6/m.1/m.1.1/attn/Transpose_3_output_0 shape: [4, 2, 49, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.strided_slice_15/StridedSlice:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.b: name: tf.compat.v1.transpose_131/transpose:0 shape: (4, 2, 49, 49) dtype: <dtype: 'float32'>
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_15/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
#
# INFO: 146 / 500
# INFO: onnx_op_type: Transpose onnx_op_name: /model.6/m.1/m.1.1/attn/Transpose_4
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/MatMul_1_output_0 shape: [4, 2, 32, 49] dtype: float32
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.linalg.matmul_15/MatMul:0 shape: (4, 2, 32, 49) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose_132/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
#
# INFO: 147 / 500
# INFO: onnx_op_type: Reshape onnx_op_name: /model.6/m.1/m.1.1/attn/Reshape_3
# INFO:  input_name.1: /model.6/m.1/m.1.1/attn/Transpose_4_output_0 shape: [4, 49, 2, 32] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m.0.0/attn/Constant_10_output_0 shape: (4,) dtype: int64
# INFO:  output_name.1: /model.6/m.1/m.1.1/attn/Reshape_5_output_0 shape: [1, 14, 14, 64] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_132/transpose:0 shape: (4, 49, 2, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [np.int64(1), np.int64(14), np.int64(14), np.int64(64)]
# ...
#   133056345488848: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056345489232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056225296464: TensorSpec(shape=(1, 1, 64, 128), dtype=tf.float32, name=None)
#   133056225296848: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225296656: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133056225297232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056225297616: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   133056225297424: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225298000: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133056225297808: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   133056225297040: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225298192: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133056225298576: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225298960: TensorSpec(shape=(1, 1, 128, 384), dtype=tf.float32, name=None)
#   133056225298768: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133056225298384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133056225300496: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225300112: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056225301072: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225300880: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133056225301456: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225301840: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133056225300304: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225299728: TensorSpec(shape=(1, 1, 128, 384), dtype=tf.float32, name=None)
#   133056225300688: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133056225302224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133056225299152: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225302416: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056225302608: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225299536: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133056225302800: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225299344: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133056225301648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225303952: TensorSpec(shape=(1, 1, 128, 384), dtype=tf.float32, name=None)
#   133056225303184: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133056225303376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133056225304144: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225305680: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056225304528: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225306064: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133056225305488: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225305104: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133056225303568: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225304912: TensorSpec(shape=(1, 1, 128, 384), dtype=tf.float32, name=None)
#   133056225302992: TensorSpec(shape=(384,), dtype=tf.float32, name=None)
#   133056225307600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133056225306640: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225307216: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056225306832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225305296: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   133056225307792: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225307984: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   133056225304336: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225306256: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   133056225303760: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056225307408: TensorSpec(shape=(1, 1, 384, 64), dtype=tf.float32, name=None)
#   133056225308176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056225307024: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133056225306448: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225309136: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056225308944: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225309328: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056225308560: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225309904: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056225309712: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225310096: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056225308368: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133056225308752: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225305872: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225310672: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056225310480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056225310864: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056225309520: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056225311056: TensorSpec(shape=(1, 1, 256, 32), dtype=tf.float32, name=None)
#   133056225311248: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056225311440: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   133056225311632: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056225312592: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   133056225312400: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056225312208: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   133056225312016: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056223740560: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   133056223740368: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056223740752: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   133056225311824: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   133056223740176: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056225310288: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   133056223741328: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   133056223741136: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223741520: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223739984: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223741904: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133056223741712: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223740944: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223743632: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   133056223743824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223745168: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133056223744976: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223745936: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056223745552: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223746512: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056223746320: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223749008: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056223748048: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223748816: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   133056223744400: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   133056223747856: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223745360: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   133056223747472: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223749200: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223748240: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056223747280: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056223749392: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   133056223747088: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   133056223747664: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056223750736: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   133056223750928: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056223751504: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133056223752272: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133056223754576: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133056223752080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223755152: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223754768: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223756112: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223755536: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223755344: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223755728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223755920: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223753424: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133056220561680: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223753232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220562256: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   133056220562064: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056223752656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133056223752848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   133056220562448: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   133056220561488: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056220563216: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   133056223749968: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   133056223742864: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   133056220563024: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   133056223749776: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   133056223742480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220561872: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   133056223750160: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   133056223743248: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056220563408: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223748624: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223742672: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220564752: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   133056220562640: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   133056223751888: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   133056223748432: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   133056223744784: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   133056223742288: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056220564176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220562832: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223751120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223749584: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223744016: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223742096: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220565328: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056220563792: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223752464: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223750544: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056223746128: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223743440: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   133056220563984: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220563600: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223753808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223750352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223745744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223743056: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220565520: TensorSpec(shape=(1, 1, 64, 6), dtype=tf.float32, name=None)
#   133056220564368: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223754960: TensorSpec(shape=(1, 1, 64, 6), dtype=tf.float32, name=None)
#   133056223751696: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056223746704: TensorSpec(shape=(1, 1, 64, 6), dtype=tf.float32, name=None)
#   133056223744592: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   133056220564560: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056220565136: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   133056223751312: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223754000: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   133056223744208: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   133056223746896: TensorSpec(shape=(6,), dtype=tf.float32, name=None)
#   133056220566672: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220566288: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220568208: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   133056220568592: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220565712: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220568976: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220568400: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220569552: TensorSpec(shape=(1, 2, 1029), dtype=tf.float32, name=None)
#   133056220569360: TensorSpec(shape=(1, 2, 1029), dtype=tf.float32, name=None)
#   133056220566480: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   133056220565904: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
# saved_model output complete!
# I0000 00:00:1748009947.664503   51681 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748009947.664658   51681 single_machine.cc:361] Starting new session
# W0000 00:00:1748009948.880202   51681 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1748009948.880243   51681 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float32 tflite output complete!
# I0000 00:00:1748009949.717414   51681 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# I0000 00:00:1748009949.717552   51681 single_machine.cc:361] Starting new session
# W0000 00:00:1748009950.728467   51681 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1748009950.728502   51681 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float16 tflite output complete!

# %%
from ultralytics import YOLO

# Load the YOLO Best or last model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Export the model to NCNN & OpenVino format
model.export(format="ncnn")
model.export(format="openvino")
# Out:
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 10, 2100) (5.2 MB)
#
# TorchScript: starting export with torch 2.6.0+cu124...
# TorchScript: export success ✅ 2.0s, saved as '/content/runs/detect/train/weights/best.torchscript' (10.3 MB)
#
# NCNN: starting export with NCNN 1.0.20250503...
# NCNN: running '/usr/local/lib/python3.11/dist-packages/ultralytics/pnnx /content/runs/detect/train/weights/best.torchscript ncnnparam=/content/runs/detect/train/weights/best_ncnn_model/model.ncnn.param ncnnbin=/content/runs/detect/train/weights/best_ncnn_model/model.ncnn.bin ncnnpy=/content/runs/detect/train/weights/best_ncnn_model/model_ncnn.py pnnxparam=/content/runs/detect/train/weights/best_ncnn_model/model.pnnx.param pnnxbin=/content/runs/detect/train/weights/best_ncnn_model/model.pnnx.bin pnnxpy=/content/runs/detect/train/weights/best_ncnn_model/model_pnnx.py pnnxonnx=/content/runs/detect/train/weights/best_ncnn_model/model.pnnx.onnx fp16=0 device=cpu inputshape="[1, 3, 320, 320]"'
# NCNN: export success ✅ 1.5s, saved as '/content/runs/detect/train/weights/best_ncnn_model' (9.9 MB)
#
# Export complete (3.9s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best_ncnn_model imgsz=320
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best_ncnn_model imgsz=320 data=/content/lettuce-3/data.yaml
# Visualize:       https://netron.app
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 10, 2100) (5.2 MB)
#
# OpenVINO: starting export with openvino 2025.1.0-18503-6fec06580ab-releases/2025/1...
# OpenVINO: export success ✅ 3.9s, saved as '/content/runs/detect/train/weights/best_openvino_model/' (10.2 MB)
#
# Export complete (5.0s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best_openvino_model imgsz=320
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best_openvino_model imgsz=320 data=/content/lettuce-3/data.yaml
# Visualize:       https://netron.app
# '/content/runs/detect/train/weights/best_openvino_model'

# %%
import shutil
import os
from google.colab import files

# Define the path to the runs folder
runs_folder_path = "/content/runs/detect/train"  # Ensure this path exists

# Check if the folder exists
if not os.path.exists(runs_folder_path):
    raise FileNotFoundError(f"The folder {runs_folder_path} does not exist. Check the path or training output.")

# Define a clean zip filename (avoid parentheses or special characters)
zip_filename = "yolov12n_50epochs_openvn_ncnn_320.zip"

# Compress the folder
shutil.make_archive(zip_filename.replace('.zip', ''), 'zip', runs_folder_path)

# Download the compressed file
files.download(zip_filename)

# %%
# Test Load the exported NCNN model
ncnn_model = YOLO("/content/runs/detect/train/weights/best_ncnn_model")

# Run inference
results = ncnn_model("/content/-_jpg.rf.4dc5bdfc63a21ebb5301b5346c14f204.jpg")
# Out:
# Loading /content/runs/detect/train/weights/best_ncnn_model for NCNN inference...
#
# image 1/1 /content/-_jpg.rf.4dc5bdfc63a21ebb5301b5346c14f204.jpg: 320x320 1 Powdery_mildew_on_lettuce, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 320)

# %%
# Test Load the exported OpenVINO model
ov_model = YOLO("/content/runs/detect/train/weights/best_openvino_model")

# Run inference
#results = ov_model("/content/164_jpg.rf.777d75b823d7a72ad21b0533ae9e9978.jpg")
results = ov_model(source='/content/-_jpg.rf.4dc5bdfc63a21ebb5301b5346c14f204.jpg', save=True, conf=0.2)

# Run inference with specified device, available devices: ["intel:gpu", "intel:npu", "intel:cpu"]
#results = ov_model("/content/164_jpg.rf.777d75b823d7a72ad21b0533ae9e9978.jpg", device="intel:gpu")
# Out:
# Loading /content/runs/detect/train/weights/best_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#
# image 1/1 /content/-_jpg.rf.4dc5bdfc63a21ebb5301b5346c14f204.jpg: 320x320 1 Powdery_mildew_on_lettuce, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 17.8ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image, display
import os

# Cek hasil pada folder 'runs/detect/predict'
output_image_path = "/content/runs/detect/predict/-_jpg.rf.4dc5bdfc63a21ebb5301b5346c14f204.jpg"
if os.path.exists(output_image_path):
    display(Image(filename=output_image_path))
else:
    print("Gambar hasil deteksi tidak ditemukan.")
